# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for i in sns.get_dataset_names():
    print(i)
# Out:
# anagrams
# anscombe
# attention
# brain_networks
# car_crashes
# diamonds
# dots
# dowjones
# exercise
# flights
# fmri
# geyser
# glue
# healthexp
# iris
# mpg
# penguins
# planets
# seaice
# taxis
# tips
# titanic

# %%
titanic_data = sns.load_dataset('titanic')
titanic_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic_data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
sns.barplot(titanic_data, x = 'embark_town', y = 'fare', hue='sex')
# Out:
# <Axes: xlabel='embark_town', ylabel='fare'>

# %% [markdown]
# <ol>
# <li> Here we come to know that Southampton embark town has least fare compared to Cherboug and Queenstown </li>
# <li> In Queenstown and Cherbourg the fare is same for both sex</li>
#     </ol>

# %%
titanic_data.dropna(axis=0, inplace=True)
titanic_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# <h1> The people who died </h1>

# %%
sns.histplot(titanic_data, x = 'deck', y = 'age', hue='alive')
# Out:
# <Axes: xlabel='deck', ylabel='age'>

# %% [markdown]
# <b> Result </b>
# <em>In the incident there was no one in Deck C who were alive and deck E has the higest no of people who still rescued</em>

# %%
sns.stripplot(titanic_data, x = 'deck', y = 'fare')
# Out:
# <Axes: xlabel='deck', ylabel='fare'>

# %% [markdown]
# Still the cost of the fair in deck C and Deck B is higher but still the number of people died in the incident were from Deck C

# %%
sns.stripplot(titanic_data, x = 'deck', y = 'fare', hue='who')
# Out:
# <Axes: xlabel='deck', ylabel='fare'>

# %% [markdown]
# From this StripPlot the deck B and C both have the equal type of people. From this we might conclude that the Deck is majorly for family

# %%
sns.stripplot(titanic_data, x = 'deck', y = 'fare', hue='alone')
# Out:
# <Axes: xlabel='deck', ylabel='fare'>

# %% [markdown]
# From the above StripPlot we come to know that the deck B and C have the family.

# %%
sns.

# %% [markdown]
# Since the costs of deck C and deck B are higher then the other deecks and majority of deaths happened in Deck C b/w the age of

# %%
sns.jointplot(titanic_data, x='age', y = 'fare', hue='sex', kind='scatter')

# %% [markdown]
# <b>Result  :</b>
# <em> Avg age of person were in range 20 to 40 and the cost of fare of the titanic for women were highr than men in the dataset</em>

# %%
# Out:
# <Axes: xlabel='deck', ylabel='fare'>

# %%
sns.jointplot(titanic_data, x='age', y = 'fare', hue='alive', kind='scatter')

# %%
sns.scatterplot(titanic_data, x='age', y='fare', hue='class')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.boxplot(titanic_data)
# Out:
# <Axes: >

# %%
plt.figure(figsize=)
sns.violinplot(titanic_data, x='class', y='fare')
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(titanic_data, x='class', y='fare', hue='sex')
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
# checking if the dataset have any null values

if titanic_data.isnull().values.any():
    print("DataFrame contains null values")

# %%
sns.barplot(titanic_data, x = 'embark_town', y = 'fare', hue='sex')
# Out:
# <Axes: xlabel='embark_town', ylabel='fare'>
